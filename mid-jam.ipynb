# %%
import pandas as pd

# %%
path = 'not_diamonds_training.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#        RecordID  carat        cut color clarity  depth  table     x     y  \
# 0             4   1.32  Very Good     G     SI2   62.9   57.0  6.94  6.98
# 1             5   0.31  Very Good     H     VS2   63.2   58.0  4.33  4.31
# 2             6   0.33      Ideal     G    VVS1   62.3   55.0  4.43  4.46
# 3             8   0.32      Ideal     G     VS2   61.8   55.0  4.40  4.43
# 4            11   0.43    Premium     E     SI2   61.0   60.0  4.94  4.87
# ...         ...    ...        ...   ...     ...    ...    ...   ...   ...
# 10782     26955   0.30      Ideal     D     VS2   62.3   56.0  4.29  4.32
# 10783     26959   0.70       Good     F     VS1   62.8   61.0  5.57  5.61
# 10784     26962   1.10      Ideal     I     VS1   61.7   57.0  6.65  6.62
# 10785     26965   0.90  Very Good     G     SI2   63.2   58.0  6.05  6.10
# 10786     26967   0.37       Good     H     VS2   63.7   55.0  4.54  4.56
#
#           z  price
# 0      4.38   6294
# 1      2.73    628
# ...

# %%
df.mean()
# Out:
# RecordID    13390.545935
# carat           0.804361
# depth          61.736418
# table          57.471558
# x               5.744979
# y               5.752459
# z               3.545974
# price        3984.204042
# dtype: float64

# %%
df.corr()
# Out:
#           RecordID     carat     depth     table         x         y  \
# RecordID  1.000000 -0.011367 -0.002248 -0.001165 -0.010442 -0.004198
# carat    -0.011367  1.000000  0.034313  0.184068  0.978215  0.898957
# depth    -0.002248  0.034313  1.000000 -0.303945 -0.018712 -0.027688
# table    -0.001165  0.184068 -0.303945  1.000000  0.201106  0.177325
# x        -0.010442  0.978215 -0.018712  0.201106  1.000000  0.916758
# y        -0.004198  0.898957 -0.027688  0.177325  0.916758  1.000000
# z        -0.008260  0.968583  0.104011  0.159928  0.983295  0.918956
# price    -0.011641  0.924384 -0.004688  0.126918  0.888810  0.818236
#
#                  z     price
# RecordID -0.008260 -0.011641
# carat     0.968583  0.924384
# depth     0.104011 -0.004688
# table     0.159928  0.126918
# x         0.983295  0.888810
# y         0.918956  0.818236
# z         1.000000  0.875461
# price     0.875461  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='x', y='y', data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x='x', y='z', data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='z'>

# %%
# add trend line
sns.regplot(x='x', y='z', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='x', ylabel='z'>

# %%
import statsmodels # optimized for insight
#import sklearn # optimized for predictions

# %%
menter_mentee_path = '/Users/mac/Downloads/Mentor Mentee Spreadsheet! - Sheet1.csv'
mdf = pd.read_csv(menter_mentee_path)

# %%
mdf
# Out:
#     Please provide your Slack Username: Which role are you signing up for?   \
# 0                                   NaN                                 NaN
# 1                         DejeneTechane                              Mentor
# 2                                Cindy                               Mentee
# 3                            Jim Lorica                              Mentee
# 4                    Uchechukwu Azubuko                              Mentor
# ..                                  ...                                 ...
# 280                        Jessica.Etoh                              Mentee
# 281                Gurjote Singh Sandhu                              Mentor
# 282                  Jennifer Eberechi                               Mentor
# 283                      Chialuka Anele                              Mentee
# 284                            Ana Heoz                              Mentee
#
# ...
